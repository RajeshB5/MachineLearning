# %% [markdown]
# # Import Libraris

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('R:\MNIT\Machine Learning\DL and ML Practical Tutorials - Package\Project 1\Car_Purchasing_Data.csv', encoding = 'ISO-8859-1')
dataset
# Out:
#        Customer Name                                    Customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           Country  Gender        Age  Annual Salary  Credit Card Debt  \
# ...

# %%
x = dataset.iloc[:,2:8]
x
# Out:
#           Country  Gender        Age  Annual Salary  Credit Card Debt  \
# 0        Bulgaria       0  41.851720    62812.09301      11609.380910
# 1          Belize       0  40.870623    66646.89292       9572.957136
# 2         Algeria       1  43.152897    53798.55112      11160.355060
# 3    Cook Islands       1  58.271369    79370.03798      14426.164850
# 4          Brazil       1  57.313749    59729.15130       5358.712177
# ..            ...     ...        ...            ...               ...
# 495         Nepal       0  41.462515    71942.40291       6995.902524
# 496      Zimbabwe       1  37.642000    56039.49793      12301.456790
# 497   Philippines       1  53.943497    68888.77805      10611.606860
# 498      Botswana       1  59.160509    49811.99062      14013.034510
# 499        marlal       1  46.731152    61370.67766       9391.341628
#
#        Net Worth
# 0    238961.2505
# 1    530973.9078
# 2    638467.1773
# 3    548599.0524
# 4    560304.0671
# ...

# %%
y = dataset.iloc[:, -1]
y
# Out:
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
#           ...
# 495    48901.44342
# 496    31491.41457
# 497    64147.28888
# 498    45442.15353
# 499    45107.22566
# Name: Car Purchase Amount, Length: 500, dtype: float64

# %% [markdown]
# # Check Null values

# %%
dataset.isnull().sum().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
LabEnc_x = LabelEncoder()
x.iloc[:,0] = LabEnc_x.fit_transform(x.iloc[:,0])
x
# Out:
#      Country  Gender        Age  Annual Salary  Credit Card Debt    Net Worth
# 0         27       0  41.851720    62812.09301      11609.380910  238961.2505
# 1         17       0  40.870623    66646.89292       9572.957136  530973.9078
# 2          1       1  43.152897    53798.55112      11160.355060  638467.1773
# 3         41       1  58.271369    79370.03798      14426.164850  548599.0524
# 4         26       1  57.313749    59729.15130       5358.712177  560304.0671
# ..       ...     ...        ...            ...               ...          ...
# 495      128       0  41.462515    71942.40291       6995.902524  541670.1016
# 496      208       1  37.642000    56039.49793      12301.456790  360419.0988
# 497      144       1  53.943497    68888.77805      10611.606860  764531.3203
# 498       24       1  59.160509    49811.99062      14013.034510  337826.6382
# 499      209       1  46.731152    61370.67766       9391.341628  462946.4924
#
# [500 rows x 6 columns]

# %%
max(x.iloc[:,0])
# Out:
# 210

# %% [markdown]
# # 210 diffrent country so it's batter to avoid dummy variable so remove it

# %%
x = x.iloc[:, 1:]
x
# Out:
#      Gender        Age  Annual Salary  Credit Card Debt    Net Worth
# 0         0  41.851720    62812.09301      11609.380910  238961.2505
# 1         0  40.870623    66646.89292       9572.957136  530973.9078
# 2         1  43.152897    53798.55112      11160.355060  638467.1773
# 3         1  58.271369    79370.03798      14426.164850  548599.0524
# 4         1  57.313749    59729.15130       5358.712177  560304.0671
# ..      ...        ...            ...               ...          ...
# 495       0  41.462515    71942.40291       6995.902524  541670.1016
# 496       1  37.642000    56039.49793      12301.456790  360419.0988
# 497       1  53.943497    68888.77805      10611.606860  764531.3203
# 498       1  59.160509    49811.99062      14013.034510  337826.6382
# 499       1  46.731152    61370.67766       9391.341628  462946.4924
#
# [500 rows x 5 columns]

# %% [markdown]
# # Create Train and test data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)
x_train.shape
# Out:
# (400, 5)

# %% [markdown]
# # Create model

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = linreg.predict(x_test)

# %%
plt.plot(y_predict,y_test)

# %%
y_test=y_test.values.reshape(-1,1)

# %%
y_test[0][0]
# Out:
# 38955.219189999996

# %%
y_predict[0]
# Out:
# 38951.813038467466

# %%
for i in range(len(y_predict)):
    print('Actual = '+str(y_test[i][0])+' Predict = '+str(y_predict[i]))
# Out:
# Actual = 38955.219189999996 Predict = 38951.813038467466
# Actual = 43401.566119999996 Predict = 43401.62030243359
# Actual = 29417.64694 Predict = 29415.15910788597
# Actual = 52150.41786 Predict = 52151.37741348001
# Actual = 38243.06228 Predict = 38241.53103047268
# Actual = 53017.26723 Predict = 53014.731275548394
# Actual = 60526.97788 Predict = 60528.39504240068
# Actual = 59538.40327 Predict = 59538.52837623112
# Actual = 37714.316589999995 Predict = 37714.422530066055
# Actual = 31300.54347 Predict = 31300.172011270748
# Actual = 46846.7305 Predict = 46847.94613144821
# Actual = 56973.18105 Predict = 56973.697408281536
# Actual = 53993.44322000001 Predict = 53993.65830206172
# Actual = 70878.29664 Predict = 70879.6017507521
# Actual = 27889.95197 Predict = 27887.767052052943
# Actual = 31526.049310000002 Predict = 31528.289507820176
# Actual = 47979.48549 Predict = 47979.98764026455
# Actual = 58667.06865 Predict = 58668.5623883164
# ...
